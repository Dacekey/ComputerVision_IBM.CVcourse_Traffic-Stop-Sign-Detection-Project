# %%
my_image_rgb = "Image_Storage/Anime_Girl.jpeg"
my_image_jun = "Image_Storage/sung_jinwoo.jpg"

# %%
from PIL import Image
image = Image.open(my_image_rgb)

# %%
image.show(title='Mina')

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
image.format
# Out:
# 'JPEG'

# %%
image.size
# Out:
# (736, 920)

# %%
image.mode
# Out:
# 'RGB'

# %%
from PIL import ImageOps
image_gray = ImageOps.grayscale(image)

# %%
image_gray.mode
# Out:
# 'L'

# %%
image_gray.save("Image_Storage/mina.png")

# %%
image_gray.quantize(2)
# Out:
# <PIL.Image.Image image mode=P size=736x920>

# %%
mina = image
m_red, m_green, m_blue = mina.split()

# %%
plt.imshow(m_red)

# %%
plt.imshow(m_green)

# %%
plt.imshow(m_blue)

# %%
import numpy as np
array = np.array(image)
print(array)
# Out:
# [[[ 37  57  84]
#   [ 40  60  87]
#   [ 42  63  90]
#   ...
#   [ 18  22  34]
#   [ 18  22  34]
#   [ 18  22  34]]
#
#  [[ 38  58  85]
#   [ 41  61  88]
#   [ 42  63  90]
#   ...
#   [ 18  22  34]
#   [ 18  22  34]
#   [ 18  22  34]]
#
#  [[ 39  60  87]
#   [ 41  62  89]
#   [ 42  63  90]
#   ...
#   [ 18  22  34]
#   [ 18  22  34]
#   [ 18  22  34]]
#
#  ...
#
#  [[ 28  47  64]
#   [ 28  47  64]
#   [ 28  47  64]
#   ...
#   [105  62  82]
#   [105  62  82]
#   [105  62  82]]
#
#  [[ 23  42  59]
#   [ 23  42  59]
#   [ 23  42  59]
#   ...
#   [101  58  78]
#   [101  58  78]
#   [101  58  78]]
#
#  [[ 42  61  78]
#   [ 42  61  78]
#   [ 42  61  78]
#   ...
#   [130  87 107]
#   [130  87 107]
#   [130  87 107]]]

# %%
import cv2
image_jun = cv2.imread(my_image_jun)
plt.imshow(image_jun)

# %%
type(image_jun)
# Out:
# numpy.ndarray

# %%
new_image = cv2.cvtColor(image_jun, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)

# %%
image_gray = cv2.cvtColor(image_jun, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray)

# %%
cv2.imwrite('Image_Storage/sungjiwoo_cv2gray.png', image_gray)
# Out:
# True

# %%
# Just to know the syntax, should not try
im_gray = cv2.imread('my_image',cv2.IMREAD_GRAYSCALE)

# %%
j_blue, j_green, j_red = image_jun[:,:,0], image_jun[:,:,1], image_jun[:,:,2]

# %%
plt.imshow(j_blue)

# %%
plt.imshow(j_green)

# %%
plt.imshow(j_red)
