# %% [markdown]
# # Reading: Training a Neural Network with Momentum and Data Augmentation

# %% [markdown]
# # **Learning Objectives**
# After completing this reading, you will be able to:
# 1. Define the concepts of Momentum and Data Augmentation in neural network training.
# 2. Explain how momentum modifies parameter updates to improve convergence speed and stability.
# 3. Identify common data augmentation techniques used to reduce overfitting in image-based models.

# %% [markdown]
# # **Introduction**
# Training deep neural networks can be challenging due to issues such as slow convergence, local minima, and overfitting. To tackle these problems, techniques have been developed to speed up learning and improve generalization. Two important methods are Momentum, which optimizes the training process, and Data Augmentation, which expands and diversifies the training data to enhance performance on unseen inputs.

# %% [markdown]
# # **Momentum**
# In standard gradient descent, parameter updates rely solely on the current gradient, which can make learning slow—especially when the loss surface has sharp curves or narrow valleys. Momentum addresses this by incorporating information from previous gradients, creating a 'velocity' that smooths updates and builds speed in consistent directions. This not only helps the optimizer move faster across flat regions but also reduces oscillations, leading to quicker convergence and potentially better solutions.
#
# The update rule for momentum is:
# ![image.png](attachment:ebbb88e1-373f-4897-8605-5837d518540c.png)

# %% [markdown]
# # **Data Augmentation**
# Data augmentation is a powerful technique for reducing overfitting, a common challenge in neural network training where the model performs well on training data but poorly on unseen data. It works by generating new, varied versions of existing training samples through random transformations such as cropping, resizing, flipping, rotating, or adding noise.
#
# By creating these variations, the dataset size effectively increases without the need for new data collection. This diversity trains the model to focus on essential features rather than memorizing exact patterns, making it more robust and better suited for real-world applications.
#
# In practice, data augmentation is often applied on the fly during training using tools such as tf.image in TensorFlow or torchvision in PyTorch, ensuring each training batch contains fresh variations for improved generalization.

# %% [markdown]
# # **Summary**
# Momentum accelerates neural network training by using past gradients to smooth updates, speed convergence, and reduce oscillations. Data augmentation combats overfitting by creating varied versions of training data through transformations, boosting model robustness and generalization without collecting new data.
